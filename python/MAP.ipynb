# %%
import gmplot 
import webbrowser
import googlemaps 
import gmaps
import time 
from make_api_orders import get_routes_from_txt




def plot_map(input_data):


	my_data = get_routes_from_txt(input_data)
	lats=[]
	longs=[]
	
	
	for item in my_data[1]:
		lats.append(item[0])
		longs.append(item[1])
		
	import gmaps
	#configure api
	gmaps.configure(api_key="AIzaSyBOaRY3hQUrF0sw1KRnlPKVu8fYrYwlJPs")
	#Define location 1 and 2

	#Create the map
	fig = gmaps.figure()
	#create the layer
	for i in range(len(lats)-1):
		coor0 = (lats[i], longs[i])
		coor1 = (lats[i+1], longs[i+1])
		
		layer = gmaps.directions.Directions(coor0, coor1,mode='car')
	#Add the layer
        
		fig.add_layer(layer)
		time.sleep(0.1)
	return (fig)

fig=plot_map("input.txt")
fig
# Out:
# {
#     "success": true
# }
# {
#     "success": true
# }
# {
#     "success": true
# }
# {
#     "success": true
# }
# {
#     "success": true
# }
# {
#     "success": true
# }
# {
#     "success": true
# }
# {
#     "location": {
#         "address": "Christ's collge, St Andrews Street, Cambridge, CB2 3BU, UK",
#         "checkInTime": 0,
#         "latitude": 52.2062306,
#         "locationName": "Christ",
#         "locationNo": "",
#         "longitude": 0.1224627,
#         "notes": ""
#     },
#     "success": true
# }
# {
#     "location": {
#         "address": "Homerton college, Hills Road, Cambridge, CB2 8PH, UK",
#         "checkInTime": 0,
#         "latitude": 52.186103,
#         "locationName": "Homerton",
#         "locationNo": "",
#         "longitude": 0.136621,
#         "notes": ""
#     },
#     "success": true
# }
# {
#     "location": {
#         "address": "Girton college, Huntingdon Road, Cambridge, CB3 0JG, UK",
#         "checkInTime": 0,
# ...
